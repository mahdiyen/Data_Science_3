# %% [markdown]
# # part 1:
# Create your own SVC class and configure it with different kernels to see if you are able to have it correctly separate the moon-dataset. You can also use a precomputed kernel. In addition, there are several parameters you can tune to for better results. Make sure to go through the documentation.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_classification
from sklearn.datasets import make_moons
# from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.svm import SVC

# %%
X, y = make_moons(n_samples=200, random_state=0, shuffle=True)

X_train, X_test = X[:100], X[100:]
y_train, y_test = y[:100], y[100:]

# %% [markdown]
# ### provides different kernels for the Support Vector Classifier, e.g. RBF or polynomial.
#
# sklearn.svm.SVC(*, C=1.0, kernel='rbf', degree=3, gamma='scale', coef0=0.0, shrinking=True, probability=False, tol=0.001, cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape='ovr', break_ties=False, random_state=None)
#
# kernel{‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’} or callable, default=’rbf’
#
# C: float, default=1.0
#
# Regularization parameter. The strength of the regularization is inversely proportional to C. Must be strictly positive. The penalty is a squared l2 penalty.
#
# degree: int, default=3
#
# Degree of the polynomial kernel function (‘poly’). Must be non-negative. Ignored by all other kernels.

# %%
def make_meshgrid(X, h=.01):
    """Create a mesh grid based on vectors X and Y."""
    if X.shape[1] > 2:
        raise ValueError('Requires a matrix of 2 features for visualization purposes.')
    
    x_min = X.min() - 1
    x_max = X.max() + 1
        
    x = np.arange(x_min, x_max, h)
        
    xx, yy = np.meshgrid(x, x)
    
    return xx, yy

# %% [markdown]
# ### POLYNOMIAL method:

# %%
svm_poly = SVC(C=5, kernel='poly', degree=2)

svm_poly.fit(X_train, y_train)
# Out:
# SVC(C=5, degree=2, kernel='poly')

# %%
xx, yy = make_meshgrid(X)
grid = np.c_[xx.ravel(), yy.ravel()]


svm_poly_pred = svm_poly.predict(grid).reshape(xx.shape)

# %%
plt.contourf(xx, yy, svm_poly_pred, cmap=plt.cm.coolwarm)
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, edgecolor='white', linewidth=1, s=50, cmap=plt.cm.coolwarm)
plt.show()

# %%
d_list = [2,3,4,5,6, 10]
for degree in d_list:
    svm_poly = SVC(C=5, kernel='poly', degree=degree)
    svm_poly.fit(X_train, y_train)
    svm_poly_pred = svm_poly.predict(grid).reshape(xx.shape)
    plt.contourf(xx, yy, svm_poly_pred, cmap=plt.cm.coolwarm)
    plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, edgecolor='white', linewidth=1, s=50, cmap=plt.cm.coolwarm)
    plt.show()

# %% [markdown]
# ### RBF method:

# %%
d_list = [2,3,4,5,6, 10]
for degree in d_list:
    svm_poly = SVC(C=5, kernel='rbf', degree=degree)
    svm_poly.fit(X_train, y_train)
    svm_poly_pred = svm_poly.predict(grid).reshape(xx.shape)
    plt.contourf(xx, yy, svm_poly_pred, cmap=plt.cm.coolwarm)
    plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, edgecolor='white', linewidth=1, s=50, cmap=plt.cm.coolwarm)
    plt.show()

# %% [markdown]
# ## Part 2:
# Classification metrics are important for measuring the performance of your model. Scikit-learn provides several options such as the classification_report and confusion_matrix functions. Another helpful option is the AUC ROC and precision-recall curve. Try to understand what these metrics mean and give arguments why one metric would be more important then others.
#
# For instance, if you have to predict whether a patient has cancer or not, the number of false negatives is probably more important than the number of false positives. This would be different if we were predicting whether a picture contains a cat or a dog – or not: it all depends on the context. Thus, it is important to understand when to use which metric.
#
# For this exercise, you can use your own dataset if that is eligable for supervised classification. Otherwise, you can use the breast cancer dataset.

# %% [markdown]
# Create and train several LogisticRegression and SVM models with different values for their hyperparameters. Make use of the model evaluation techniques that have been described during the plenary part to determine the best model for this dataset. Accompany you elaborations with a conclusion, in which you explicitely interpret these evaluation and describe why the different metrics you are using are important or not. Make sure you take the context of this dataset into account.

# %% [markdown]
# #### Steps:
# 1.Try to understand the dataset globally.
#
# 2.Load the data.
#
# 3.Exploratory analysis
#
# 4.Preprocess data (skewness, normality, etc.)
#
# 5.Modeling (cross-validation and training)

# %%
# Load the data:
data = pd.read_csv('../data/breast-cancer.csv')
print (data.shape)
data.head(5)
# Out:
# (569, 32)
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
data.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# concavity_worst            float64
# concave points_worst       float64
# symmetry_worst             float64
# fractal_dimension_worst    float64
# dtype: object

# %%
#check balans in perentage using value_counts and normalize =True
data.diagnosis.value_counts(normalize=True)
# Out:
# B    0.627417
# M    0.372583
# Name: diagnosis, dtype: float64

# %%
data.isnull()
# Out:
#         id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    False      False        False         False           False      False
# 1    False      False        False         False           False      False
# 2    False      False        False         False           False      False
# 3    False      False        False         False           False      False
# 4    False      False        False         False           False      False
# ..     ...        ...          ...           ...             ...        ...
# 564  False      False        False         False           False      False
# 565  False      False        False         False           False      False
# 566  False      False        False         False           False      False
# 567  False      False        False         False           False      False
# 568  False      False        False         False           False      False
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0              False             False           False                False
# 1              False             False           False                False
# 2              False             False           False                False
# 3              False             False           False                False
# 4              False             False           False                False
# ..               ...               ...             ...                  ...
# 564            False             False           False                False
# 565            False             False           False                False
# 566            False             False           False                False
# 567            False             False           False                False
# 568            False             False           False                False
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0    ...         False          False            False       False
# 1    ...         False          False            False       False
# 2    ...         False          False            False       False
# 3    ...         False          False            False       False
# 4    ...         False          False            False       False
# ..   ...           ...            ...              ...         ...
# 564  ...         False          False            False       False
# 565  ...         False          False            False       False
# 566  ...         False          False            False       False
# 567  ...         False          False            False       False
# 568  ...         False          False            False       False
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 0               False              False            False
# 1               False              False            False
# 2               False              False            False
# 3               False              False            False
# 4               False              False            False
# ..                ...                ...              ...
# 564             False              False            False
# 565             False              False            False
# 566             False              False            False
# 567             False              False            False
# 568             False              False            False
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                   False           False                    False
# 1                   False           False                    False
# 2                   False           False                    False
# 3                   False           False                    False
# 4                   False           False                    False
# ..                    ...             ...                      ...
# 564                 False           False                    False
# 565                 False           False                    False
# 566                 False           False                    False
# 567                 False           False                    False
# 568                 False           False                    False
#
# [569 rows x 32 columns]

# %%
# clean data
data = data.drop('id',axis=1) # To prepare the data for correlation
# Mapping Benign to 0 and Malignant to 1 
data['diagnosis'] = data['diagnosis'].map({'M':1,'B':0})

# %%
float_columns = [x for x in data.columns if x not in ['diagnosis']]

# %%
# The correlation matrix
corr_mat = data.corr()
    
corr_mat
# Out:
#                          diagnosis  radius_mean  texture_mean  perimeter_mean  \
# diagnosis                 1.000000     0.727980      0.415185        0.741996
# radius_mean               0.727980     1.000000      0.318346        0.998017
# texture_mean              0.415185     0.318346      1.000000        0.322669
# perimeter_mean            0.741996     0.998017      0.322669        1.000000
# area_mean                 0.727979     0.999465      0.319679        0.997281
# smoothness_mean           0.358560     0.152087     -0.023389        0.188234
# compactness_mean          0.600909     0.492571      0.237095        0.541800
# concavity_mean            0.709769     0.653618      0.306604        0.690108
# concave points_mean       0.781475     0.797439      0.293868        0.823452
# symmetry_mean             0.330499     0.128959      0.071401        0.161561
# fractal_dimension_mean   -0.013274    -0.345094     -0.076457       -0.297124
# radius_se                 0.612239     0.645868      0.303846        0.653428
# texture_se                0.011292    -0.120079      0.420835       -0.113451
# perimeter_se              0.633373     0.645758      0.336155        0.660781
# area_se                   0.724995     0.802044      0.356754        0.807605
# smoothness_se            -0.067163    -0.276346      0.006628       -0.261600
# compactness_se            0.296425     0.189903      0.193757        0.234592
# concavity_se              0.273987     0.191910      0.154944        0.227377
# concave points_se         0.409618     0.368922      0.164277        0.402040
# symmetry_se              -0.008045    -0.141546      0.008665       -0.124704
# fractal_dimension_se      0.078769    -0.069580      0.055003       -0.032696
# radius_worst              0.786108     0.975933      0.348637        0.976416
# texture_worst             0.456903     0.299314      0.912045        0.305471
# perimeter_worst           0.793910     0.971613      0.353002        0.976866
# area_worst                0.784118     0.975917      0.347764        0.976047
# smoothness_worst          0.421465     0.105461      0.077503        0.136902
# compactness_worst         0.602957     0.436392      0.276816        0.480721
# concavity_worst           0.679810     0.549617      0.302070        0.587564
# concave points_worst      0.793566     0.741947      0.295316        0.770810
# symmetry_worst            0.415900     0.168476      0.104075        0.194044
# fractal_dimension_worst   0.324416     0.000531      0.118702        0.046200
#
#                          area_mean  smoothness_mean  compactness_mean  \
# diagnosis                 0.727979         0.358560          0.600909
# radius_mean               0.999465         0.152087          0.492571
# texture_mean              0.319679        -0.023389          0.237095
# perimeter_mean            0.997281         0.188234          0.541800
# area_mean                 1.000000         0.140885          0.481178
# smoothness_mean           0.140885         1.000000          0.663873
# compactness_mean          0.481178         0.663873          1.000000
# concavity_mean            0.647029         0.524513          0.887457
# concave points_mean       0.789748         0.555805          0.834434
# symmetry_mean             0.119882         0.557775          0.600340
# fractal_dimension_mean   -0.356358         0.585325          0.563320
# radius_se                 0.646644         0.321294          0.525333
# texture_se               -0.121116         0.089312          0.061896
# perimeter_se              0.645708         0.333000          0.599533
# area_se                   0.803702         0.299066          0.552564
# smoothness_se            -0.282751         0.332894          0.134893
# compactness_se            0.183692         0.322288          0.743788
# concavity_se              0.189220         0.260004          0.599671
# concave points_se         0.365556         0.382147          0.649147
# symmetry_se              -0.148899         0.200375          0.220772
# fractal_dimension_se     -0.073708         0.284807          0.510659
# radius_worst              0.977022         0.201604          0.531776
# texture_worst             0.301981         0.036072          0.249309
# perimeter_worst           0.972417         0.225814          0.583683
# area_worst                0.978046         0.188693          0.517857
# smoothness_worst          0.098204         0.805324          0.571112
# compactness_worst         0.429506         0.481421          0.878121
# concavity_worst           0.545970         0.436713          0.824687
# concave points_worst      0.736811         0.503053          0.820806
# symmetry_worst            0.162359         0.395056          0.506257
# fractal_dimension_worst  -0.006294         0.501116          0.691042
#
#                          concavity_mean  concave points_mean  symmetry_mean  \
# diagnosis                      0.709769             0.781475       0.330499
# radius_mean                    0.653618             0.797439       0.128959
# texture_mean                   0.306604             0.293868       0.071401
# perimeter_mean                 0.690108             0.823452       0.161561
# area_mean                      0.647029             0.789748       0.119882
# smoothness_mean                0.524513             0.555805       0.557775
# compactness_mean               0.887457             0.834434       0.600340
# concavity_mean                 1.000000             0.925341       0.498109
# concave points_mean            0.925341             1.000000       0.462297
# symmetry_mean                  0.498109             0.462297       1.000000
# fractal_dimension_mean         0.333889             0.167030       0.479810
# radius_se                      0.647480             0.722455       0.334326
# texture_se                     0.089170             0.036048       0.147608
# perimeter_se                   0.691833             0.748453       0.364689
# area_se                        0.689651             0.793746       0.303175
# smoothness_se                  0.093742             0.025606       0.187822
# compactness_se                 0.676493             0.496380       0.423321
# concavity_se                   0.709150             0.464969       0.350869
# concave points_se              0.691472             0.623195       0.393529
# symmetry_se                    0.167163             0.090515       0.449103
# fractal_dimension_se           0.449200             0.260240       0.332683
# radius_worst                   0.678598             0.817425       0.173206
# texture_worst                  0.306762             0.294542       0.090651
# perimeter_worst                0.716120             0.839650       0.202381
# area_worst                     0.670378             0.808195       0.161543
# smoothness_worst               0.457063             0.456938       0.426675
# compactness_worst              0.778127             0.689409       0.472821
# concavity_worst                0.894757             0.772976       0.425368
# concave points_worst           0.873077             0.914746       0.430297
# symmetry_worst                 0.411063             0.377154       0.704904
# fractal_dimension_worst        0.523907             0.374532       0.439321
#
#                          ...  radius_worst  texture_worst  perimeter_worst  \
# diagnosis                ...      0.786108       0.456903         0.793910
# radius_mean              ...      0.975933       0.299314         0.971613
# texture_mean             ...      0.348637       0.912045         0.353002
# perimeter_mean           ...      0.976416       0.305471         0.976866
# area_mean                ...      0.977022       0.301981         0.972417
# smoothness_mean          ...      0.201604       0.036072         0.225814
# compactness_mean         ...      0.531776       0.249309         0.583683
# concavity_mean           ...      0.678598       0.306762         0.716120
# concave points_mean      ...      0.817425       0.294542         0.839650
# symmetry_mean            ...      0.173206       0.090651         0.202381
# fractal_dimension_mean   ...     -0.286202      -0.051167        -0.240258
# radius_se                ...      0.696523       0.225672         0.691594
# texture_se               ...     -0.126840       0.457216        -0.123631
# perimeter_se             ...      0.692923       0.260515         0.708791
# area_se                  ...      0.844492       0.301909         0.837891
# smoothness_se            ...     -0.280101      -0.074678        -0.272636
# compactness_se           ...      0.195407       0.144676         0.250572
# concavity_se             ...      0.192158       0.110986         0.234080
# concave points_se        ...      0.357549       0.087450         0.395197
# symmetry_se              ...     -0.158945      -0.078432        -0.142654
# fractal_dimension_se     ...     -0.060153      -0.002719        -0.024583
# radius_worst             ...      1.000000       0.362890         0.994359
# texture_worst            ...      0.362890       1.000000         0.368713
# perimeter_worst          ...      0.994359       0.368713         1.000000
# area_worst               ...      0.998996       0.363109         0.993250
# smoothness_worst         ...      0.206941       0.225429         0.227693
# compactness_worst        ...      0.504896       0.359795         0.560110
# concavity_worst          ...      0.604899       0.372835         0.650518
# concave points_worst     ...      0.793406       0.359755         0.824036
# symmetry_worst           ...      0.254375       0.233877         0.279995
# fractal_dimension_worst  ...      0.090320       0.218710         0.138309
#
#                          area_worst  smoothness_worst  compactness_worst  \
# diagnosis                  0.784118          0.421465           0.602957
# radius_mean                0.975917          0.105461           0.436392
# texture_mean               0.347764          0.077503           0.276816
# perimeter_mean             0.976047          0.136902           0.480721
# area_mean                  0.978046          0.098204           0.429506
# smoothness_mean            0.188693          0.805324           0.481421
# compactness_mean           0.517857          0.571112           0.878121
# concavity_mean             0.670378          0.457063           0.778127
# concave points_mean        0.808195          0.456938           0.689409
# symmetry_mean              0.161543          0.426675           0.472821
# fractal_dimension_mean    -0.300993          0.505474           0.454654
# radius_se                  0.692384          0.164607           0.323763
# texture_se                -0.127577         -0.047031          -0.085911
# perimeter_se               0.688304          0.173054           0.413283
# area_se                    0.843874          0.179656           0.393461
# smoothness_se             -0.285938          0.315240          -0.057930
# compactness_se             0.187519          0.230972           0.687094
# concavity_se               0.188696          0.180016           0.523184
# concave points_se          0.351802          0.217016           0.474651
# symmetry_se               -0.169806         -0.013535           0.041768
# fractal_dimension_se      -0.065979          0.171685           0.395928
# radius_worst               0.998996          0.206941           0.504896
# texture_worst              0.363109          0.225429           0.359795
# perimeter_worst            0.993250          0.227693           0.560110
# area_worst                 1.000000          0.196587           0.494315
# smoothness_worst           0.196587          1.000000           0.577616
# compactness_worst          0.494315          0.577616           1.000000
# concavity_worst            0.598773          0.526372           0.902511
# concave points_worst       0.784989          0.547691           0.820673
# symmetry_worst             0.242285          0.499255           0.608453
# fractal_dimension_worst    0.079351          0.619849           0.803747
#
#                          concavity_worst  concave points_worst  \
# diagnosis                       0.679810              0.793566
# radius_mean                     0.549617              0.741947
# texture_mean                    0.302070              0.295316
# perimeter_mean                  0.587564              0.770810
# area_mean                       0.545970              0.736811
# smoothness_mean                 0.436713              0.503053
# compactness_mean                0.824687              0.820806
# concavity_mean                  0.894757              0.873077
# concave points_mean             0.772976              0.914746
# symmetry_mean                   0.425368              0.430297
# fractal_dimension_mean          0.327544              0.175167
# radius_se                       0.413554              0.562919
# texture_se                     -0.065115             -0.100699
# perimeter_se                    0.483759              0.612998
# area_se                         0.495668              0.666350
# smoothness_se                  -0.067828             -0.101957
# compactness_se                  0.638593              0.487894
# concavity_se                    0.674564              0.463650
# concave points_se               0.563799              0.604606
# symmetry_se                     0.013088             -0.032090
# fractal_dimension_se            0.372062              0.216193
# radius_worst                    0.604899              0.793406
# texture_worst                   0.372835              0.359755
# perimeter_worst                 0.650518              0.824036
# area_worst                      0.598773              0.784989
# smoothness_worst                0.526372              0.547691
# compactness_worst               0.902511              0.820673
# concavity_worst                 1.000000              0.876467
# concave points_worst            0.876467              1.000000
# symmetry_worst                  0.528304              0.503556
# fractal_dimension_worst         0.674640              0.513140
#
#                          symmetry_worst  fractal_dimension_worst
# diagnosis                      0.415900                 0.324416
# radius_mean                    0.168476                 0.000531
# texture_mean                   0.104075                 0.118702
# perimeter_mean                 0.194044                 0.046200
# area_mean                      0.162359                -0.006294
# smoothness_mean                0.395056                 0.501116
# compactness_mean               0.506257                 0.691042
# concavity_mean                 0.411063                 0.523907
# concave points_mean            0.377154                 0.374532
# symmetry_mean                  0.704904                 0.439321
# fractal_dimension_mean         0.330029                 0.769124
# radius_se                      0.119841                 0.069769
# texture_se                    -0.119950                -0.034583
# perimeter_se                   0.152905                 0.136911
# area_se                        0.156170                 0.064843
# smoothness_se                 -0.111314                 0.102131
# compactness_se                 0.272559                 0.594062
# concavity_se                   0.201628                 0.453672
# concave points_se              0.139366                 0.312700
# symmetry_se                    0.377148                 0.076173
# fractal_dimension_se           0.107492                 0.593865
# radius_worst                   0.254375                 0.090320
# texture_worst                  0.233877                 0.218710
# perimeter_worst                0.279995                 0.138309
# area_worst                     0.242285                 0.079351
# smoothness_worst               0.499255                 0.619849
# compactness_worst              0.608453                 0.803747
# concavity_worst                0.528304                 0.674640
# concave points_worst           0.503556                 0.513140
# symmetry_worst                 1.000000                 0.537049
# fractal_dimension_worst        0.537049                 1.000000
#
# [31 rows x 31 columns]

# %%
# The correlation matrix
corr_mat = data[float_columns].corr()

# Strip out the diagonal values for the next step
for x in range(len(float_columns)):
    corr_mat.iloc[x,x] = 0.0
    
corr_mat
# Out:
#                          radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                 0.000000      0.318346        0.998017   0.999465
# texture_mean                0.318346      0.000000        0.322669   0.319679
# perimeter_mean              0.998017      0.322669        0.000000   0.997281
# area_mean                   0.999465      0.319679        0.997281   0.000000
# smoothness_mean             0.152087     -0.023389        0.188234   0.140885
# compactness_mean            0.492571      0.237095        0.541800   0.481178
# concavity_mean              0.653618      0.306604        0.690108   0.647029
# concave points_mean         0.797439      0.293868        0.823452   0.789748
# symmetry_mean               0.128959      0.071401        0.161561   0.119882
# fractal_dimension_mean     -0.345094     -0.076457       -0.297124  -0.356358
# radius_se                   0.645868      0.303846        0.653428   0.646644
# texture_se                 -0.120079      0.420835       -0.113451  -0.121116
# perimeter_se                0.645758      0.336155        0.660781   0.645708
# area_se                     0.802044      0.356754        0.807605   0.803702
# smoothness_se              -0.276346      0.006628       -0.261600  -0.282751
# compactness_se              0.189903      0.193757        0.234592   0.183692
# concavity_se                0.191910      0.154944        0.227377   0.189220
# concave points_se           0.368922      0.164277        0.402040   0.365556
# symmetry_se                -0.141546      0.008665       -0.124704  -0.148899
# fractal_dimension_se       -0.069580      0.055003       -0.032696  -0.073708
# radius_worst                0.975933      0.348637        0.976416   0.977022
# texture_worst               0.299314      0.912045        0.305471   0.301981
# perimeter_worst             0.971613      0.353002        0.976866   0.972417
# area_worst                  0.975917      0.347764        0.976047   0.978046
# smoothness_worst            0.105461      0.077503        0.136902   0.098204
# compactness_worst           0.436392      0.276816        0.480721   0.429506
# concavity_worst             0.549617      0.302070        0.587564   0.545970
# concave points_worst        0.741947      0.295316        0.770810   0.736811
# symmetry_worst              0.168476      0.104075        0.194044   0.162359
# fractal_dimension_worst     0.000531      0.118702        0.046200  -0.006294
#
#                          smoothness_mean  compactness_mean  concavity_mean  \
# radius_mean                     0.152087          0.492571        0.653618
# texture_mean                   -0.023389          0.237095        0.306604
# perimeter_mean                  0.188234          0.541800        0.690108
# area_mean                       0.140885          0.481178        0.647029
# smoothness_mean                 0.000000          0.663873        0.524513
# compactness_mean                0.663873          0.000000        0.887457
# concavity_mean                  0.524513          0.887457        0.000000
# concave points_mean             0.555805          0.834434        0.925341
# symmetry_mean                   0.557775          0.600340        0.498109
# fractal_dimension_mean          0.585325          0.563320        0.333889
# radius_se                       0.321294          0.525333        0.647480
# texture_se                      0.089312          0.061896        0.089170
# perimeter_se                    0.333000          0.599533        0.691833
# area_se                         0.299066          0.552564        0.689651
# smoothness_se                   0.332894          0.134893        0.093742
# compactness_se                  0.322288          0.743788        0.676493
# concavity_se                    0.260004          0.599671        0.709150
# concave points_se               0.382147          0.649147        0.691472
# symmetry_se                     0.200375          0.220772        0.167163
# fractal_dimension_se            0.284807          0.510659        0.449200
# radius_worst                    0.201604          0.531776        0.678598
# texture_worst                   0.036072          0.249309        0.306762
# perimeter_worst                 0.225814          0.583683        0.716120
# area_worst                      0.188693          0.517857        0.670378
# smoothness_worst                0.805324          0.571112        0.457063
# compactness_worst               0.481421          0.878121        0.778127
# concavity_worst                 0.436713          0.824687        0.894757
# concave points_worst            0.503053          0.820806        0.873077
# symmetry_worst                  0.395056          0.506257        0.411063
# fractal_dimension_worst         0.501116          0.691042        0.523907
#
#                          concave points_mean  symmetry_mean  \
# radius_mean                         0.797439       0.128959
# texture_mean                        0.293868       0.071401
# perimeter_mean                      0.823452       0.161561
# area_mean                           0.789748       0.119882
# smoothness_mean                     0.555805       0.557775
# compactness_mean                    0.834434       0.600340
# concavity_mean                      0.925341       0.498109
# concave points_mean                 0.000000       0.462297
# symmetry_mean                       0.462297       0.000000
# fractal_dimension_mean              0.167030       0.479810
# radius_se                           0.722455       0.334326
# texture_se                          0.036048       0.147608
# perimeter_se                        0.748453       0.364689
# area_se                             0.793746       0.303175
# smoothness_se                       0.025606       0.187822
# compactness_se                      0.496380       0.423321
# concavity_se                        0.464969       0.350869
# concave points_se                   0.623195       0.393529
# symmetry_se                         0.090515       0.449103
# fractal_dimension_se                0.260240       0.332683
# radius_worst                        0.817425       0.173206
# texture_worst                       0.294542       0.090651
# perimeter_worst                     0.839650       0.202381
# area_worst                          0.808195       0.161543
# smoothness_worst                    0.456938       0.426675
# compactness_worst                   0.689409       0.472821
# concavity_worst                     0.772976       0.425368
# concave points_worst                0.914746       0.430297
# symmetry_worst                      0.377154       0.704904
# fractal_dimension_worst             0.374532       0.439321
#
#                          fractal_dimension_mean  ...  radius_worst  \
# radius_mean                           -0.345094  ...      0.975933
# texture_mean                          -0.076457  ...      0.348637
# perimeter_mean                        -0.297124  ...      0.976416
# area_mean                             -0.356358  ...      0.977022
# smoothness_mean                        0.585325  ...      0.201604
# compactness_mean                       0.563320  ...      0.531776
# concavity_mean                         0.333889  ...      0.678598
# concave points_mean                    0.167030  ...      0.817425
# symmetry_mean                          0.479810  ...      0.173206
# fractal_dimension_mean                 0.000000  ...     -0.286202
# radius_se                              0.009495  ...      0.696523
# texture_se                             0.172877  ...     -0.126840
# perimeter_se                           0.063441  ...      0.692923
# area_se                               -0.107895  ...      0.844492
# smoothness_se                          0.402400  ...     -0.280101
# compactness_se                         0.560146  ...      0.195407
# concavity_se                           0.449874  ...      0.192158
# concave points_se                      0.339920  ...      0.357549
# symmetry_se                            0.344694  ...     -0.158945
# fractal_dimension_se                   0.688167  ...     -0.060153
# radius_worst                          -0.286202  ...      0.000000
# texture_worst                         -0.051167  ...      0.362890
# perimeter_worst                       -0.240258  ...      0.994359
# area_worst                            -0.300993  ...      0.998996
# smoothness_worst                       0.505474  ...      0.206941
# compactness_worst                      0.454654  ...      0.504896
# concavity_worst                        0.327544  ...      0.604899
# concave points_worst                   0.175167  ...      0.793406
# symmetry_worst                         0.330029  ...      0.254375
# fractal_dimension_worst                0.769124  ...      0.090320
#
#                          texture_worst  perimeter_worst  area_worst  \
# radius_mean                   0.299314         0.971613    0.975917
# texture_mean                  0.912045         0.353002    0.347764
# perimeter_mean                0.305471         0.976866    0.976047
# area_mean                     0.301981         0.972417    0.978046
# smoothness_mean               0.036072         0.225814    0.188693
# compactness_mean              0.249309         0.583683    0.517857
# concavity_mean                0.306762         0.716120    0.670378
# concave points_mean           0.294542         0.839650    0.808195
# symmetry_mean                 0.090651         0.202381    0.161543
# fractal_dimension_mean       -0.051167        -0.240258   -0.300993
# radius_se                     0.225672         0.691594    0.692384
# texture_se                    0.457216        -0.123631   -0.127577
# perimeter_se                  0.260515         0.708791    0.688304
# area_se                       0.301909         0.837891    0.843874
# smoothness_se                -0.074678        -0.272636   -0.285938
# compactness_se                0.144676         0.250572    0.187519
# concavity_se                  0.110986         0.234080    0.188696
# concave points_se             0.087450         0.395197    0.351802
# symmetry_se                  -0.078432        -0.142654   -0.169806
# fractal_dimension_se         -0.002719        -0.024583   -0.065979
# radius_worst                  0.362890         0.994359    0.998996
# texture_worst                 0.000000         0.368713    0.363109
# perimeter_worst               0.368713         0.000000    0.993250
# area_worst                    0.363109         0.993250    0.000000
# smoothness_worst              0.225429         0.227693    0.196587
# compactness_worst             0.359795         0.560110    0.494315
# concavity_worst               0.372835         0.650518    0.598773
# concave points_worst          0.359755         0.824036    0.784989
# symmetry_worst                0.233877         0.279995    0.242285
# fractal_dimension_worst       0.218710         0.138309    0.079351
#
#                          smoothness_worst  compactness_worst  concavity_worst  \
# radius_mean                      0.105461           0.436392         0.549617
# texture_mean                     0.077503           0.276816         0.302070
# perimeter_mean                   0.136902           0.480721         0.587564
# area_mean                        0.098204           0.429506         0.545970
# smoothness_mean                  0.805324           0.481421         0.436713
# compactness_mean                 0.571112           0.878121         0.824687
# concavity_mean                   0.457063           0.778127         0.894757
# concave points_mean              0.456938           0.689409         0.772976
# symmetry_mean                    0.426675           0.472821         0.425368
# fractal_dimension_mean           0.505474           0.454654         0.327544
# radius_se                        0.164607           0.323763         0.413554
# texture_se                      -0.047031          -0.085911        -0.065115
# perimeter_se                     0.173054           0.413283         0.483759
# area_se                          0.179656           0.393461         0.495668
# smoothness_se                    0.315240          -0.057930        -0.067828
# compactness_se                   0.230972           0.687094         0.638593
# concavity_se                     0.180016           0.523184         0.674564
# concave points_se                0.217016           0.474651         0.563799
# symmetry_se                     -0.013535           0.041768         0.013088
# fractal_dimension_se             0.171685           0.395928         0.372062
# radius_worst                     0.206941           0.504896         0.604899
# texture_worst                    0.225429           0.359795         0.372835
# perimeter_worst                  0.227693           0.560110         0.650518
# area_worst                       0.196587           0.494315         0.598773
# smoothness_worst                 0.000000           0.577616         0.526372
# compactness_worst                0.577616           0.000000         0.902511
# concavity_worst                  0.526372           0.902511         0.000000
# concave points_worst             0.547691           0.820673         0.876467
# symmetry_worst                   0.499255           0.608453         0.528304
# fractal_dimension_worst          0.619849           0.803747         0.674640
#
#                          concave points_worst  symmetry_worst  \
# radius_mean                          0.741947        0.168476
# texture_mean                         0.295316        0.104075
# perimeter_mean                       0.770810        0.194044
# area_mean                            0.736811        0.162359
# smoothness_mean                      0.503053        0.395056
# compactness_mean                     0.820806        0.506257
# concavity_mean                       0.873077        0.411063
# concave points_mean                  0.914746        0.377154
# symmetry_mean                        0.430297        0.704904
# fractal_dimension_mean               0.175167        0.330029
# radius_se                            0.562919        0.119841
# texture_se                          -0.100699       -0.119950
# perimeter_se                         0.612998        0.152905
# area_se                              0.666350        0.156170
# smoothness_se                       -0.101957       -0.111314
# compactness_se                       0.487894        0.272559
# concavity_se                         0.463650        0.201628
# concave points_se                    0.604606        0.139366
# symmetry_se                         -0.032090        0.377148
# fractal_dimension_se                 0.216193        0.107492
# radius_worst                         0.793406        0.254375
# texture_worst                        0.359755        0.233877
# perimeter_worst                      0.824036        0.279995
# area_worst                           0.784989        0.242285
# smoothness_worst                     0.547691        0.499255
# compactness_worst                    0.820673        0.608453
# concavity_worst                      0.876467        0.528304
# concave points_worst                 0.000000        0.503556
# symmetry_worst                       0.503556        0.000000
# fractal_dimension_worst              0.513140        0.537049
#
#                          fractal_dimension_worst
# radius_mean                             0.000531
# texture_mean                            0.118702
# perimeter_mean                          0.046200
# area_mean                              -0.006294
# smoothness_mean                         0.501116
# compactness_mean                        0.691042
# concavity_mean                          0.523907
# concave points_mean                     0.374532
# symmetry_mean                           0.439321
# fractal_dimension_mean                  0.769124
# radius_se                               0.069769
# texture_se                             -0.034583
# perimeter_se                            0.136911
# area_se                                 0.064843
# smoothness_se                           0.102131
# compactness_se                          0.594062
# concavity_se                            0.453672
# concave points_se                       0.312700
# symmetry_se                             0.076173
# fractal_dimension_se                    0.593865
# radius_worst                            0.090320
# texture_worst                           0.218710
# perimeter_worst                         0.138309
# area_worst                              0.079351
# smoothness_worst                        0.619849
# compactness_worst                       0.803747
# concavity_worst                         0.674640
# concave points_worst                    0.513140
# symmetry_worst                          0.537049
# fractal_dimension_worst                 0.000000
#
# [30 rows x 30 columns]

# %%
# see with features are highly correlated
# Pairwise maximal correlations
corr_mat.abs().idxmax()
# Out:
# radius_mean                              area_mean
# texture_mean                         texture_worst
# perimeter_mean                         radius_mean
# area_mean                              radius_mean
# smoothness_mean                   smoothness_worst
# compactness_mean                    concavity_mean
# concavity_mean                 concave points_mean
# concave points_mean                 concavity_mean
# symmetry_mean                       symmetry_worst
# fractal_dimension_mean     fractal_dimension_worst
# radius_se                             perimeter_se
# texture_se                           texture_worst
# perimeter_se                             radius_se
# area_se                                  radius_se
# smoothness_se                 fractal_dimension_se
# compactness_se                        concavity_se
# concavity_se                        compactness_se
# concave points_se                     concavity_se
# symmetry_se                          symmetry_mean
# fractal_dimension_se                compactness_se
# radius_worst                            area_worst
# texture_worst                         texture_mean
# perimeter_worst                       radius_worst
# area_worst                            radius_worst
# smoothness_worst                   smoothness_mean
# compactness_worst                  concavity_worst
# concavity_worst                  compactness_worst
# concave points_worst           concave points_mean
# symmetry_worst                       symmetry_mean
# fractal_dimension_worst          compactness_worst
# dtype: object

# %%
# how much are they correlated? Can we eliminate certain features based on high correlations
corr_mat.abs().max()
# Out:
# radius_mean                0.999465
# texture_mean               0.912045
# perimeter_mean             0.998017
# area_mean                  0.999465
# smoothness_mean            0.805324
# compactness_mean           0.887457
# concavity_mean             0.925341
# concave points_mean        0.925341
# symmetry_mean              0.704904
# fractal_dimension_mean     0.769124
# radius_se                  0.960671
# texture_se                 0.457216
# perimeter_se               0.960671
# area_se                    0.951101
# smoothness_se              0.428325
# compactness_se             0.822292
# concavity_se               0.822292
# concave points_se          0.784603
# symmetry_se                0.449103
# fractal_dimension_se       0.802681
# radius_worst               0.998996
# texture_worst              0.912045
# perimeter_worst            0.994359
# area_worst                 0.998996
# smoothness_worst           0.805324
# compactness_worst          0.902511
# concavity_worst            0.902511
# concave points_worst       0.914746
# symmetry_worst             0.704904
# fractal_dimension_worst    0.803747
# dtype: float64

# %%
# .skew 0: no skew, + right skew, - left skew, look for above .75 
skew_columns = (data[float_columns]
                .skew()
                .sort_values(ascending=False))

skew_columns = skew_columns.loc[skew_columns > 0.75]
skew_columns
# Out:
# area_se                    5.447186
# concavity_se               5.110463
# fractal_dimension_se       3.923969
# perimeter_se               3.443615
# radius_se                  3.088612
# smoothness_se              2.314450
# symmetry_se                2.195133
# compactness_se             1.902221
# area_worst                 1.859373
# fractal_dimension_worst    1.662579
# texture_se                 1.646444
# area_mean                  1.645732
# compactness_worst          1.473555
# concave points_se          1.444678
# symmetry_worst             1.433928
# concavity_mean             1.401180
# fractal_dimension_mean     1.304489
# compactness_mean           1.190123
# concave points_mean        1.171180
# concavity_worst            1.150237
# perimeter_worst            1.128164
# radius_worst               1.103115
# perimeter_mean             0.990650
# radius_mean                0.942380
# dtype: float64

# %%
import numpy as np
# Perform log transform on skewed columns
for col in skew_columns.index.tolist():
    data[col] = np.log1p(data[col])

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
data[float_columns] = sc.fit_transform(data[float_columns])

data.head(4)
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1     1.138030     -2.073335        1.281628   1.130319
# 1          1     1.711783     -0.353632        1.597721   1.713327
# 2          1     1.524183      0.456187        1.509470   1.511457
# 3          1    -0.774335      0.253732       -0.550424  -0.843470
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         1.568466          3.150675        2.567947             2.487638
# 1        -0.826962         -0.481575        0.011104             0.571874
# 2         0.942210          1.076890        1.393265             2.021815
# 3         3.283553          3.256221        1.908415             1.460738
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0       2.217515  ...      1.764045      -1.359293         2.022158
# 1       0.001392  ...      1.706795      -0.369203         1.502321
# 2       0.939685  ...      1.490832      -0.023974         1.362620
# 3       2.867383  ...     -0.179580       0.133984        -0.130272
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0    1.794344          1.307686           2.479386         2.003224
# 1    1.737118         -0.375612          -0.411700        -0.077623
# 2    1.493444          0.527407           1.146233         0.929353
# 3   -0.494860          3.394275           3.449402         1.907919
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0              2.296076        2.682614                 1.939736
# 1              1.087084       -0.228740                 0.292501
# 2              1.955000        1.177854                 0.211979
# 3              2.175786        5.487455                 4.813255
#
# [4 rows x 31 columns]

# %%
# sns.set_context('notebook')
# sns.pairplot(data[float_columns + ['diagnosis']], 
#              hue='diagnosis');

# %% [markdown]
# ### Warning: I had to make the above code comment because the size of file should be less than 25 mb to be uploade on the github

# %% [markdown]
# ### ROC
# ROC Curve: Plot of False Positive Rate (x) vs. True Positive Rate (y).
#
# ROC analysis does not have any bias toward models that perform well on the minority class at the expense of the majority class—a property that is quite attractive when dealing with imbalanced data.

# %%
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1     1.138030     -2.073335        1.281628   1.130319
# 1          1     1.711783     -0.353632        1.597721   1.713327
# 2          1     1.524183      0.456187        1.509470   1.511457
# 3          1    -0.774335      0.253732       -0.550424  -0.843470
# 4          1     1.652935     -1.151816        1.663405   1.667470
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         1.568466          3.150675        2.567947             2.487638
# 1        -0.826962         -0.481575        0.011104             0.571874
# 2         0.942210          1.076890        1.393265             2.021815
# 3         3.283553          3.256221        1.908415             1.460738
# 4         0.280372          0.569623        1.400416             1.438255
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0       2.217515  ...      1.764045      -1.359293         2.022158
# 1       0.001392  ...      1.706795      -0.369203         1.502321
# 2       0.939685  ...      1.490832      -0.023974         1.362620
# 3       2.867383  ...     -0.179580       0.133984        -0.130272
# 4      -0.009560  ...      1.326223      -1.466770         1.355825
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0    1.794344          1.307686           2.479386         2.003224
# 1    1.737118         -0.375612          -0.411700        -0.077623
# 2    1.493444          0.527407           1.146233         0.929353
# 3   -0.494860          3.394275           3.449402         1.907919
# 4    1.346061          0.220556          -0.280508         0.700235
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0              2.296076        2.682614                 1.939736
# 1              1.087084       -0.228740                 0.292501
# 2              1.955000        1.177854                 0.211979
# 3              2.175786        5.487455                 4.813255
# 4              0.729259       -0.888983                -0.395358
#
# [5 rows x 31 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
# Modeling
diagnosis = data['diagnosis']
X = data.drop('diagnosis', axis=1)

# %%
from sklearn.model_selection import train_test_split

y_train, y_test,X_train, X_test = train_test_split(diagnosis,X, test_size = 0.2)

# %%
# Logistic Regression
# Logistic Regression
lr_params = {
    'C': [0.1, 1.0, 10.0],  # Different values for the regularization parameter C
    'solver': ['liblinear', 'saga']  # Different solvers to use
}

lr_model = GridSearchCV(LogisticRegression(), lr_params, cv=5)
lr_model.fit(X_train, y_train)
# Out:
# C:\Users\Mahdiye\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Mahdiye\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Mahdiye\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Mahdiye\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Mahdiye\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Mahdiye\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Mahdiye\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Mahdiye\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Mahdiye\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Mahdiye\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Mahdiye\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Mahdiye\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Mahdiye\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Mahdiye\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Mahdiye\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [0.1, 1.0, 10.0],
#                          'solver': ['liblinear', 'saga']})

# %%
# Support Vector Machine (SVM)
d_list = [2,3,4,5,6,7,8,9,10]
svm_params = {
    'C': [0.1, 1.0, 10.0],  # Different values for the regularization parameter C
    'kernel': ['linear', 'rbf','poly'], # Different kernel functions to use
    'degree' : d_list 
}

svm_model = GridSearchCV(SVC(), svm_params, cv=5)
svm_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.1, 1.0, 10.0],
#                          'degree': [2, 3, 4, 5, 6, 7, 8, 9, 10],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
# Print the best hyperparameters and the accuracy of the models
print("Logistic Regression:")
print("Best hyperparameters:", lr_model.best_params_)
print("Accuracy:", lr_model.best_score_)

print("\nSupport Vector Machine (SVM):")
print("Best hyperparameters:", svm_model.best_params_)
print("Accuracy:", svm_model.best_score_)
# Out:
# Logistic Regression:
# Best hyperparameters: {'C': 10.0, 'solver': 'saga'}
# Accuracy: 0.9824175824175825
#
# Support Vector Machine (SVM):
# Best hyperparameters: {'C': 1.0, 'degree': 2, 'kernel': 'linear'}
# Accuracy: 0.9824175824175825

# %%
from sklearn.datasets import make_classification
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import confusion_matrix

# %%
#SVM-poly
clf = SVC(C= 0.1, degree= 3, kernel= 'poly')
clf.fit(X_train, y_train)
# Out:
# SVC(C=0.1, kernel='poly')

# %%
#SVM-rbf
clf1 = SVC(C= 0.1, degree= 3, kernel= 'rbf')
clf1.fit(X_train, y_train)
# Out:
# SVC(C=0.1)

# %%
#SVM-rbf
clf2 = SVC(C= 1.0, degree= 2, kernel= 'linear')
clf2.fit(X_train, y_train)
# Out:
# SVC(degree=2, kernel='linear')

# %%
# Logistic Regression
clf3 = LogisticRegression(C=0.1, solver='saga')
clf3.fit(X_train, y_train)
# Out:
# C:\Users\Mahdiye\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# LogisticRegression(C=0.1, solver='saga')

# %%
y_pred = clf.decision_function(X_test)#poly
y_pred1 = clf1.decision_function(X_test)#rbf
y_pred2 = clf2.decision_function(X_test)#linear
y_pred3 = clf2.decision_function(X_test)#lR

# %%
binary_pred = (y_pred > 0).astype(int)

# Calculate the confusion matrix
confusion = confusion_matrix(y_test, binary_pred)
confusion
# Out:
# array([[63,  0],
#        [19, 32]], dtype=int64)

# %%
# Create a single plot
fig, ax = plt.subplots()

# Plot the ROC curve for logistic regression
lr_display = RocCurveDisplay.from_predictions(y_test, y_pred, name='SVM-poly', ax=ax)

# Plot the ROC curve for SVM-rbf
poly_display = RocCurveDisplay.from_predictions(y_test, y_pred1, name='SVM-rbf', ax=ax)

# Plot the ROC curve for SVM-linear
poly_display = RocCurveDisplay.from_predictions(y_test, y_pred2, name='SVM-linear', ax=ax)

# Plot the ROC curve for Logistic Regression
rbf_display = RocCurveDisplay.from_predictions(y_test, y_pred3, name='Logistic Regression', ax=ax)

# Add a legend
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### Explanation:
# The model with higher accuracy is generally considered better at correctly predicting the target variable. Now here almost all models have better predictions.
